# %%
from core.config import config
from rich import print as rprint

# %%
def get_llm():
    """返回 LLM 实例，未配置 key 时返回 None。"""
    if not config.LLM_API_KEY:
        return None
    from langchain.chat_models import init_chat_model
    return init_chat_model(
        model=config.LLM_MODEL,
        api_key=config.LLM_API_KEY,
        base_url=config.LLM_BASE_URL,
        temperature=0,
        model_provider="deepseek",
    )


llm = get_llm()
response = llm.invoke("翻译如下的汉字：你好世界")
rprint(response)
# Out:
# AIMessage(
#     content='你好世界的英文翻译是 **"Hello, World!"**。  \n\n如果是其他语种或上下文中的特殊含义，可以补充说明哦～
# 😊',
#     additional_kwargs={
#         'refusal': None,
#         'reasoning_content':
# '嗯，用户要求翻译一段简单的中文短语。需要先确认短语的准确含义和常见英文对应表达。\n\n"你好世界"是中文里对"Hello
# World"的直译，通常用作编程或技术领域的标准示例短语。考虑直接采用技术社区通用的英文表达，这样既准确又能保持术语一致
# 性。\n\n想到不需要额外解释，因为用户明确要求的是翻译而非释义。直接给出对应的英文翻译即可。'
#     },
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 129,
#             'prompt_tokens': 254,
#             'total_tokens': 383,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 94,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 192}
#         },
#         'model_provider': 'deepseek',
#         'model_name': 'mimo-v2.5',
#         'system_fingerprint': None,
#         'id': '971d73b0c6324a8ab2342e1b0a364532',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='lc_run--019f32cd-c798-7053-9cea-182edcb92be6-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 254,
#         'output_tokens': 129,
#         'total_tokens': 383,
#         'input_token_details': {'cache_read': 192},
#         'output_token_details': {'reasoning': 94}
#     }
# )
